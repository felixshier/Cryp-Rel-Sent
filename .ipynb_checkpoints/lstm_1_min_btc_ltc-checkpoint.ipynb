# %% [markdown]
# # 10 MINUTE DATA

# %% [markdown]
# ## MODEL 1: ALL FEATURES

# %%
# %reset -f

# %%
# imports

import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
# read data

march_df = pd.read_csv("BTC_10min_ETH_10min_march.csv")
april_df = pd.read_csv("BTC_10min_ETH_10min_april.csv")

# %%
# combine data

df = pd.concat([march_df, april_df], axis=0)

# split testing and training data

train_size = int(np.round(df.shape[0]*0.90))
test_size = int(np.round(df.shape[0]*0.10))

training_set = df.iloc[:train_size, 1:]
test_set = df.iloc[test_size:, 1:]

# %%
training_set.head()
# Out:
#    BTC Polarity  BTC Subjectivity  BTC Price  BTC Volume USD  ETH Polarity  \
# 0      0.059776          0.247396   45346.19     11649.92686      0.024760
# 1      0.060227          0.227976   45289.97    313492.75750      0.060539
# 2      0.072547          0.242424   46340.26    590826.20210      0.106064
# 3      0.082249          0.275825   46473.16    315746.03920      0.036179
# 4      0.101809          0.300476   46555.87    203311.87260      0.022930
#
#    ETH Subjectivity  ETH Price  ETH Volume USD  Net Polarity  \
# 0          0.299496    1428.53     40722.93557      0.035016
# 1          0.322566    1420.54         0.00000     -0.000311
# 2          0.332174    1448.57     49394.48724     -0.033517
# 3          0.296867    1449.17     68768.92247      0.046069
# 4          0.317710    1445.92     81577.03215      0.078879
#
#    Net Subjectivity    Net Volume  Price Ratio
# 0         -0.052101  -29073.00871     0.031503
# 1         -0.094590  313492.75750     0.031365
# 2         -0.089750  541431.71486     0.031259
# 3         -0.021042  246977.11673     0.031183
# 4         -0.017233  121734.84045     0.031058

# %%
test_set.head()
# Out:
#      BTC Polarity  BTC Subjectivity  BTC Price  BTC Volume USD  ETH Polarity  \
# 850      0.102714          0.299668   48648.93     1266.818137      0.046874
# 851      0.090503          0.284943   48592.81   260150.012000      0.066194
# 852      0.070822          0.243996   48678.81   168693.683200      0.045281
# 853      0.067182          0.303544   48606.79    21562.122240      0.090686
# 854      0.101192          0.284924   48652.82      784.472231      0.036569
#
#      ETH Subjectivity  ETH Price  ETH Volume USD  Net Polarity  \
# 850          0.365025    1640.00    1.829677e+06      0.055841
# 851          0.300029    1640.33    1.141728e+05      0.024308
# 852          0.355852    1648.08    9.589411e+03      0.025541
# 853          0.370060    1645.54    6.203615e+04     -0.023504
# 854          0.353766    1645.79    5.443107e+04      0.064622
#
#      Net Subjectivity    Net Volume  Price Ratio
# 850         -0.065356 -1.828410e+06     0.033711
# 851         -0.015086  1.459773e+05     0.033757
# 852         -0.111857  1.591043e+05     0.033856
# 853         -0.066516 -4.047403e+04     0.033854
# 854         -0.068842 -5.364660e+04     0.033827

# %%
# feature scaling

x_sc = MinMaxScaler(feature_range = (0, 1))
y_sc = MinMaxScaler(feature_range = (0, 1))

training_set.iloc[:, 0:11] = x_sc.fit_transform(training_set.iloc[:, 0:11])
training_set['Price Ratio'] = y_sc.fit_transform(training_set['Price Ratio'].values.reshape(-1,1))
training_set_scaled = training_set.values

# %%
# creating a data structure with 6 time-steps and 1 output
window = 12

X_train = []
y_train = []
for i in range(window, train_size):
    X_train.append(training_set_scaled[i-window:i, 0:11])
    y_train.append(training_set_scaled[i, -1])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 11))

# %%
X_train.shape
# Out:
# (7634, 12, 11)

# %%
y_train.shape
# Out:
# (7634,)

# %%
# model

model_1 = Sequential()

#Adding the first LSTM layer and some Dropout regularisation
model_1.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))
model_1.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
model_1.add(LSTM(units = 50, return_sequences = True))
model_1.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
model_1.add(LSTM(units = 50, return_sequences = True))
model_1.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
model_1.add(LSTM(units = 50))
model_1.add(Dropout(0.2))

# Adding the output layer
model_1.add(Dense(units = 1))

# Compiling the RNN
model_1.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set

history_1 = model_1.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 239/239 [==============================] - 11s 20ms/step - loss: 0.0071
# Epoch 2/100
# 239/239 [==============================] - 4s 19ms/step - loss: 0.0013
# Epoch 3/100
# 239/239 [==============================] - 4s 19ms/step - loss: 0.0012
# Epoch 4/100
# 239/239 [==============================] - 4s 19ms/step - loss: 0.0010
# Epoch 5/100
# 239/239 [==============================] - 5s 20ms/step - loss: 9.2909e-04
# Epoch 6/100
# 239/239 [==============================] - 4s 19ms/step - loss: 9.2543e-04
# Epoch 7/100
# 239/239 [==============================] - 4s 19ms/step - loss: 8.6253e-04
# Epoch 8/100
# 239/239 [==============================] - 5s 20ms/step - loss: 7.4073e-04
# Epoch 9/100
# 239/239 [==============================] - 4s 19ms/step - loss: 7.3546e-04
# Epoch 10/100
# 239/239 [==============================] - 4s 19ms/step - loss: 7.6998e-04
# Epoch 11/100
# 239/239 [==============================] - 5s 19ms/step - loss: 6.5251e-04
# Epoch 12/100
# 239/239 [==============================] - 5s 20ms/step - loss: 6.7833e-04
# Epoch 13/100
# 239/239 [==============================] - 5s 19ms/step - loss: 6.2767e-04
# Epoch 14/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.8026e-04
# Epoch 15/100
# 239/239 [==============================] - 5s 20ms/step - loss: 6.0489e-04
# Epoch 16/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.9669e-04
# Epoch 17/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.5361e-04
# Epoch 18/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.7604e-04
# Epoch 19/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.9638e-04
# Epoch 20/100
# 239/239 [==============================] - 4s 19ms/step - loss: 5.9536e-04
# Epoch 21/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.3622e-04
# Epoch 22/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.7904e-04
# Epoch 23/100
# 239/239 [==============================] - 5s 19ms/step - loss: 6.2619e-04
# Epoch 24/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.0590e-04
# Epoch 25/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.3051e-04
# Epoch 26/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.9060e-04
# Epoch 27/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.1383e-04
# Epoch 28/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.0338e-04
# Epoch 29/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.1569e-04
# Epoch 30/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.1727e-04
# Epoch 31/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.6445e-04
# Epoch 32/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.6918e-04
# Epoch 33/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.1837e-04
# Epoch 34/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.5063e-04
# Epoch 35/100
# 239/239 [==============================] - 5s 19ms/step - loss: 5.3335e-04
# Epoch 36/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.5346e-04
# Epoch 37/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.8810e-04
# Epoch 38/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.9502e-04
# Epoch 39/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.0740e-04
# Epoch 40/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.8983e-04
# Epoch 41/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.3231e-04
# Epoch 42/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.9003e-04
# Epoch 43/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.8702e-04
# Epoch 44/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.3701e-04
# Epoch 45/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.3845e-04
# Epoch 46/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.6885e-04
# Epoch 47/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.4932e-04
# Epoch 48/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.2633e-04
# Epoch 49/100
# 239/239 [==============================] - 5s 23ms/step - loss: 5.1452e-04
# Epoch 50/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.5301e-04
# Epoch 51/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.5056e-04
# Epoch 52/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.5142e-04
# Epoch 53/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.5248e-04
# Epoch 54/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.4598e-04
# Epoch 55/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.4968e-04
# Epoch 56/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.3983e-04
# Epoch 57/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.6382e-04
# Epoch 58/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.4017e-04
# Epoch 59/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.6963e-04
# Epoch 60/100
# 239/239 [==============================] - 5s 22ms/step - loss: 4.4663e-04
# Epoch 61/100
# 239/239 [==============================] - 6s 24ms/step - loss: 4.5050e-04
# Epoch 62/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.9469e-04
# Epoch 63/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.8207e-04
# Epoch 64/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.2939e-04
# Epoch 65/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.2763e-04
# Epoch 66/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.1393e-04
# Epoch 67/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.1999e-04
# Epoch 68/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.3112e-04
# Epoch 69/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.5961e-04
# Epoch 70/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.3989e-04
# Epoch 71/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.1619e-04
# Epoch 72/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.2449e-04
# Epoch 73/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.2919e-04
# Epoch 74/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.1892e-04
# Epoch 75/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.6918e-04
# Epoch 76/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.0919e-04
# Epoch 77/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.2049e-04
# Epoch 78/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.4576e-04
# Epoch 79/100
# 239/239 [==============================] - 5s 19ms/step - loss: 3.9760e-04
# Epoch 80/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.6894e-04
# Epoch 81/100
# 239/239 [==============================] - 5s 19ms/step - loss: 3.9422e-04
# Epoch 82/100
# 239/239 [==============================] - 5s 19ms/step - loss: 3.7617e-04
# Epoch 83/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.3253e-04
# Epoch 84/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.2246e-04
# Epoch 85/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.1353e-04
# Epoch 86/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.2456e-04
# Epoch 87/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.9223e-04
# Epoch 88/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.1916e-04
# Epoch 89/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.1063e-04
# Epoch 90/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.5115e-04
# Epoch 91/100
# 239/239 [==============================] - 5s 19ms/step - loss: 3.9872e-04
# Epoch 92/100
# 239/239 [==============================] - 5s 22ms/step - loss: 4.2837e-04
# Epoch 93/100
# 239/239 [==============================] - 6s 24ms/step - loss: 4.3259e-04
# Epoch 94/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.0485e-04
# Epoch 95/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.0553e-04
# Epoch 96/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.1523e-04
# Epoch 97/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.2121e-04
# Epoch 98/100
# 239/239 [==============================] - 5s 19ms/step - loss: 4.2366e-04
# Epoch 99/100
# 239/239 [==============================] - 5s 19ms/step - loss: 3.8401e-04
# Epoch 100/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.0154e-04

# %%
plt.plot(history_1.history['loss'])
#plt.plot(history_1.history['val_loss'])
plt.title('model 1 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# prep inputs to get predictions

dataset_train = df.iloc[:train_size, 1:]
dataset_test = df.iloc[train_size:, 1:]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)

dataset_total.iloc[:, 0:11] = x_sc.fit_transform(dataset_total.iloc[:, 0:11])
dataset_total['Price Ratio'] = y_sc.fit_transform(dataset_total['Price Ratio'].values.reshape(-1,1))

inputs = dataset_total[len(dataset_total) - len(dataset_test) - window:].values
inputs = inputs.reshape(-1,12)

X_test = []
for i in range(window, test_size+window):
    X_test.append(inputs[i-window:i, 0:11])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 11))

# get predictions

predicted_values = model_1.predict(X_test)
predicted_values = y_sc.inverse_transform(predicted_values)

# %%
# visualising the results

plt.figure(figsize=(10, 5))
plt.plot(df.iloc[train_size:, 0], dataset_test['Price Ratio'].values, color = 'red', label = 'Real Price Ratio')
plt.plot(df.iloc[train_size:, 0], predicted_values, color = 'blue', label = 'Predicted Price Ratio')
plt.xticks(np.arange(0,test_size,50))
plt.title('Model 1 Price Ratio Prediction')
plt.xlabel('Time')
plt.ylabel('Price Ratio')
plt.legend()

plt.show()

# %%
# rmse

rmse = mean_squared_error(dataset_test['Price Ratio'].values, predicted_values, squared=False)
print(rmse)
# Out:
# 0.0013783996284023707

# %% [markdown]
# ## MODEL 2: ONLY SENTIMENT DATA

# %%
# %reset -f

# %%
# imports

import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
# read data

march_df = pd.read_csv("BTC_10min_ETH_10min_march.csv")
april_df = pd.read_csv("BTC_10min_ETH_10min_april.csv")

# %%
# combine data

df = pd.concat([march_df, april_df], axis=0)

df = df[["Timestamp", "BTC Polarity", "ETH Polarity", "BTC Subjectivity", "ETH Subjectivity", "Net Polarity", "Net Subjectivity", "Price Ratio"]]

# split testing and training data

train_size = int(np.round(df.shape[0]*0.90))
test_size = int(np.round(df.shape[0]*0.10))

training_set = df.iloc[:train_size, 1:]
test_set = df.iloc[test_size:, 1:]

# %%
training_set.head()
# Out:
#    BTC Polarity  ETH Polarity  BTC Subjectivity  ETH Subjectivity  \
# 0      0.059776      0.024760          0.247396          0.299496
# 1      0.060227      0.060539          0.227976          0.322566
# 2      0.072547      0.106064          0.242424          0.332174
# 3      0.082249      0.036179          0.275825          0.296867
# 4      0.101809      0.022930          0.300476          0.317710
#
#    Net Polarity  Net Subjectivity  Price Ratio
# 0      0.035016         -0.052101     0.031503
# 1     -0.000311         -0.094590     0.031365
# 2     -0.033517         -0.089750     0.031259
# 3      0.046069         -0.021042     0.031183
# 4      0.078879         -0.017233     0.031058

# %%
test_set.head()
# Out:
#      BTC Polarity  ETH Polarity  BTC Subjectivity  ETH Subjectivity  \
# 850      0.102714      0.046874          0.299668          0.365025
# 851      0.090503      0.066194          0.284943          0.300029
# 852      0.070822      0.045281          0.243996          0.355852
# 853      0.067182      0.090686          0.303544          0.370060
# 854      0.101192      0.036569          0.284924          0.353766
#
#      Net Polarity  Net Subjectivity  Price Ratio
# 850      0.055841         -0.065356     0.033711
# 851      0.024308         -0.015086     0.033757
# 852      0.025541         -0.111857     0.033856
# 853     -0.023504         -0.066516     0.033854
# 854      0.064622         -0.068842     0.033827

# %%
# feature scaling

x_sc = MinMaxScaler(feature_range = (0, 1))
y_sc = MinMaxScaler(feature_range = (0, 1))

training_set.iloc[:, 0:6] = x_sc.fit_transform(training_set.iloc[:, 0:6])
training_set['Price Ratio'] = y_sc.fit_transform(training_set['Price Ratio'].values.reshape(-1,1))
training_set_scaled = training_set.values

# %%
# creating a data structure with 6 time-steps and 1 output

window = 12

X_train = []
y_train = []
for i in range(window, train_size):
    X_train.append(training_set_scaled[i-window:i, 0:6])
    y_train.append(training_set_scaled[i, -1])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 6))

# %%
X_train.shape
# Out:
# (7634, 12, 6)

# %%
y_train.shape
# Out:
# (7634,)

# %%
# model

model_2 = Sequential()

#Adding the first LSTM layer and some Dropout regularisation
model_2.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))
model_2.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
model_2.add(LSTM(units = 50, return_sequences = True))
model_2.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
model_2.add(LSTM(units = 50, return_sequences = True))
model_2.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
model_2.add(LSTM(units = 50))
model_2.add(Dropout(0.2))

# Adding the output layer
model_2.add(Dense(units = 1))

# Compiling the RNN
model_2.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set

history_2 = model_2.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 239/239 [==============================] - 11s 19ms/step - loss: 0.0428
# Epoch 2/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0401
# Epoch 3/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0396
# Epoch 4/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0382
# Epoch 5/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0371
# Epoch 6/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0358
# Epoch 7/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0354
# Epoch 8/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0349
# Epoch 9/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0349
# Epoch 10/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0340
# Epoch 11/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0335
# Epoch 12/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0339
# Epoch 13/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0334
# Epoch 14/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0335
# Epoch 15/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0328
# Epoch 16/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0321
# Epoch 17/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0323
# Epoch 18/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0322
# Epoch 19/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0325
# Epoch 20/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0323
# Epoch 21/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0315
# Epoch 22/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0317
# Epoch 23/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0316
# Epoch 24/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0311
# Epoch 25/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0313
# Epoch 26/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0313
# Epoch 27/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0311
# Epoch 28/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0311
# Epoch 29/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0307
# Epoch 30/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0310
# Epoch 31/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0304
# Epoch 32/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0304
# Epoch 33/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0303
# Epoch 34/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0304
# Epoch 35/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0297
# Epoch 36/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0298
# Epoch 37/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0301
# Epoch 38/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0300
# Epoch 39/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0295
# Epoch 40/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0296
# Epoch 41/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0293
# Epoch 42/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0288
# Epoch 43/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0292
# Epoch 44/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0282
# Epoch 45/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0286
# Epoch 46/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0283
# Epoch 47/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0279
# Epoch 48/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0282
# Epoch 49/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0279
# Epoch 50/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0277
# Epoch 51/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0276
# Epoch 52/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0276
# Epoch 53/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0273
# Epoch 54/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0286
# Epoch 55/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0270
# Epoch 56/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0269
# Epoch 57/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0265
# Epoch 58/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0269
# Epoch 59/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0263
# Epoch 60/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0260
# Epoch 61/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0264
# Epoch 62/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0264
# Epoch 63/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0259
# Epoch 64/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0252
# Epoch 65/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0253
# Epoch 66/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0253
# Epoch 67/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0252
# Epoch 68/100
# 239/239 [==============================] - 5s 19ms/step - loss: 0.0251
# Epoch 69/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0250
# Epoch 70/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0245
# Epoch 71/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0243
# Epoch 72/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0247
# Epoch 73/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0242
# Epoch 74/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0234
# Epoch 75/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0234
# Epoch 76/100
# 239/239 [==============================] - 5s 23ms/step - loss: 0.0228
# Epoch 77/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0226
# Epoch 78/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0226
# Epoch 79/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0217
# Epoch 80/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0219
# Epoch 81/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0209
# Epoch 82/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0207
# Epoch 83/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0202
# Epoch 84/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0204
# Epoch 85/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0200
# Epoch 86/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0192
# Epoch 87/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0194
# Epoch 88/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0185
# Epoch 89/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0178
# Epoch 90/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0184
# Epoch 91/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0179
# Epoch 92/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0171
# Epoch 93/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0166
# Epoch 94/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0166
# Epoch 95/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0160
# Epoch 96/100
# 239/239 [==============================] - 5s 23ms/step - loss: 0.0153
# Epoch 97/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0161
# Epoch 98/100
# 239/239 [==============================] - 5s 22ms/step - loss: 0.0148
# Epoch 99/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0146
# Epoch 100/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0137

# %%
plt.plot(history_2.history['loss'])
#plt.plot(history_2.history['val_loss'])
plt.title('model 2 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# prep inputs to get predictions

dataset_train = df.iloc[:train_size, 1:]
dataset_test = df.iloc[train_size:, 1:]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)

dataset_total.iloc[:, 0:6] = x_sc.fit_transform(dataset_total.iloc[:, 0:6])
dataset_total['Price Ratio'] = y_sc.fit_transform(dataset_total['Price Ratio'].values.reshape(-1,1))

inputs = dataset_total[len(dataset_total) - len(dataset_test) - window:].values
inputs = inputs.reshape(-1,7)

X_test = []
for i in range(window, test_size+window):
    X_test.append(inputs[i-window:i, 0:6])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 6))

# get predictions

predicted_values = model_2.predict(X_test)
predicted_values = y_sc.inverse_transform(predicted_values)

# %%
# visualising the results

plt.figure(figsize=(10, 5))
plt.plot(df.iloc[train_size:, 0], dataset_test['Price Ratio'].values, color = 'red', label = 'Real Price Ratio')
plt.plot(df.iloc[train_size:, 0], predicted_values, color = 'blue', label = 'Predicted Price Ratio')
plt.xticks(np.arange(0,test_size,50))
plt.title('Model 2 Price Ratio Prediction')
plt.xlabel('Time')
plt.ylabel('Price Ratio')
plt.legend()

plt.show()

# %%
# rmse

rmse = mean_squared_error(dataset_test['Price Ratio'].values, predicted_values, squared=False)
print(rmse)
# Out:
# 0.01097990140084373

# %% [markdown]
# ## MODEL 3: ONLY FINANCIAL DATA

# %%
# %reset -f

# %%
# imports

import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
# read data

march_df = pd.read_csv("BTC_10min_ETH_10min_march.csv")
april_df = pd.read_csv("BTC_10min_ETH_10min_april.csv")

# %%
# combine data

df = pd.concat([march_df, april_df], axis=0)

df = df[["Timestamp", "BTC Price", "ETH Price", "BTC Volume USD", "ETH Volume USD", "Net Volume", "Price Ratio"]]

# split testing and training data

train_size = int(np.round(df.shape[0]*0.90))
test_size = int(np.round(df.shape[0]*0.10))

training_set = df.iloc[:train_size, 1:]
test_set = df.iloc[test_size:, 1:]

# %%
training_set.head()
# Out:
#    BTC Price  ETH Price  BTC Volume USD  ETH Volume USD    Net Volume  \
# 0   45346.19    1428.53     11649.92686     40722.93557  -29073.00871
# 1   45289.97    1420.54    313492.75750         0.00000  313492.75750
# 2   46340.26    1448.57    590826.20210     49394.48724  541431.71486
# 3   46473.16    1449.17    315746.03920     68768.92247  246977.11673
# 4   46555.87    1445.92    203311.87260     81577.03215  121734.84045
#
#    Price Ratio
# 0     0.031503
# 1     0.031365
# 2     0.031259
# 3     0.031183
# 4     0.031058

# %%
test_set.head()
# Out:
#      BTC Price  ETH Price  BTC Volume USD  ETH Volume USD    Net Volume  \
# 850   48648.93    1640.00     1266.818137    1.829677e+06 -1.828410e+06
# 851   48592.81    1640.33   260150.012000    1.141728e+05  1.459773e+05
# 852   48678.81    1648.08   168693.683200    9.589411e+03  1.591043e+05
# 853   48606.79    1645.54    21562.122240    6.203615e+04 -4.047403e+04
# 854   48652.82    1645.79      784.472231    5.443107e+04 -5.364660e+04
#
#      Price Ratio
# 850     0.033711
# 851     0.033757
# 852     0.033856
# 853     0.033854
# 854     0.033827

# %%
# feature scaling

x_sc = MinMaxScaler(feature_range = (0, 1))
y_sc = MinMaxScaler(feature_range = (0, 1))

training_set.iloc[:, 0:5] = x_sc.fit_transform(training_set.iloc[:, 0:5])
training_set['Price Ratio'] = y_sc.fit_transform(training_set['Price Ratio'].values.reshape(-1,1))
training_set_scaled = training_set.values

# %%
# creating a data structure with 6 time-steps and 1 output

window = 12

X_train = []
y_train = []
for i in range(window, train_size):
    X_train.append(training_set_scaled[i-window:i, 0:5])
    y_train.append(training_set_scaled[i, -1])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 5))

# %%
X_train.shape
# Out:
# (7634, 12, 5)

# %%
y_train.shape
# Out:
# (7634,)

# %%
# model

model_3 = Sequential()

#Adding the first LSTM layer and some Dropout regularisation
model_3.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))
model_3.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
model_3.add(LSTM(units = 50, return_sequences = True))
model_3.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
model_3.add(LSTM(units = 50, return_sequences = True))
model_3.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
model_3.add(LSTM(units = 50))
model_3.add(Dropout(0.2))

# Adding the output layer
model_3.add(Dense(units = 1))

# Compiling the RNN
model_3.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set

history_3 = model_3.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 239/239 [==============================] - 11s 20ms/step - loss: 0.0060
# Epoch 2/100
# 239/239 [==============================] - 5s 21ms/step - loss: 0.0012
# Epoch 3/100
# 239/239 [==============================] - 5s 20ms/step - loss: 0.0011
# Epoch 4/100
# 239/239 [==============================] - 5s 20ms/step - loss: 8.8709e-04
# Epoch 5/100
# 239/239 [==============================] - 5s 20ms/step - loss: 9.1842e-04
# Epoch 6/100
# 239/239 [==============================] - 5s 21ms/step - loss: 8.2175e-04
# Epoch 7/100
# 239/239 [==============================] - 5s 20ms/step - loss: 7.2536e-04
# Epoch 8/100
# 239/239 [==============================] - 5s 20ms/step - loss: 7.3775e-04
# Epoch 9/100
# 239/239 [==============================] - 5s 21ms/step - loss: 7.0967e-04
# Epoch 10/100
# 239/239 [==============================] - 5s 20ms/step - loss: 6.3016e-04
# Epoch 11/100
# 239/239 [==============================] - 5s 20ms/step - loss: 6.2452e-04
# Epoch 12/100
# 239/239 [==============================] - 5s 20ms/step - loss: 6.4523e-04
# Epoch 13/100
# 239/239 [==============================] - 5s 20ms/step - loss: 6.7738e-04
# Epoch 14/100
# 239/239 [==============================] - 5s 20ms/step - loss: 6.1610e-04
# Epoch 15/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.6000e-04
# Epoch 16/100
# 239/239 [==============================] - 5s 21ms/step - loss: 5.6539e-04
# Epoch 17/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.2748e-04
# Epoch 18/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.1399e-04
# Epoch 19/100
# 239/239 [==============================] - 5s 21ms/step - loss: 5.0664e-04
# Epoch 20/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.0267e-04
# Epoch 21/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.7929e-04
# Epoch 22/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.8721e-04
# Epoch 23/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.4960e-04
# Epoch 24/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.1845e-04
# Epoch 25/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.1439e-04
# Epoch 26/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.8668e-04
# Epoch 27/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.7653e-04
# Epoch 28/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.8159e-04
# Epoch 29/100
# 239/239 [==============================] - 5s 21ms/step - loss: 5.2721e-04
# Epoch 30/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.0073e-04
# Epoch 31/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.0488e-04
# Epoch 32/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.5438e-04
# Epoch 33/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.7293e-04
# Epoch 34/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.5073e-04
# Epoch 35/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.2569e-04
# Epoch 36/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.6603e-04
# Epoch 37/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.4469e-04
# Epoch 38/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.8776e-04
# Epoch 39/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.3125e-04
# Epoch 40/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.2977e-04
# Epoch 41/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.6897e-04
# Epoch 42/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.4035e-04
# Epoch 43/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.3083e-04
# Epoch 44/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.7749e-04
# Epoch 45/100
# 239/239 [==============================] - 5s 20ms/step - loss: 5.1235e-04
# Epoch 46/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.8390e-04
# Epoch 47/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.7342e-04
# Epoch 48/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.3562e-04
# Epoch 49/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.8282e-04
# Epoch 50/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.9458e-04
# Epoch 51/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.2708e-04
# Epoch 52/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.8271e-04
# Epoch 53/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.2164e-04
# Epoch 54/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.4850e-04
# Epoch 55/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.4448e-04
# Epoch 56/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.4383e-04
# Epoch 57/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.0300e-04
# Epoch 58/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.2118e-04
# Epoch 59/100
# 239/239 [==============================] - 5s 22ms/step - loss: 4.3049e-04
# Epoch 60/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.4355e-04
# Epoch 61/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.2756e-04
# Epoch 62/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.3838e-04
# Epoch 63/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.1500e-04
# Epoch 64/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.1701e-04
# Epoch 65/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.3021e-04
# Epoch 66/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.0302e-04
# Epoch 67/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.4476e-04
# Epoch 68/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.0738e-04
# Epoch 69/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.1725e-04
# Epoch 70/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.2007e-04
# Epoch 71/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.1354e-04
# Epoch 72/100
# 239/239 [==============================] - 5s 22ms/step - loss: 4.1953e-04
# Epoch 73/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.0112e-04
# Epoch 74/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.9205e-04
# Epoch 75/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.1623e-04
# Epoch 76/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.3027e-04
# Epoch 77/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.2727e-04
# Epoch 78/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.0904e-04
# Epoch 79/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.8127e-04
# Epoch 80/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.3790e-04
# Epoch 81/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.9442e-04
# Epoch 82/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.1400e-04
# Epoch 83/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.1058e-04
# Epoch 84/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.1725e-04
# Epoch 85/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.2014e-04
# Epoch 86/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.9479e-04
# Epoch 87/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.9466e-04
# Epoch 88/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.2243e-04
# Epoch 89/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.4524e-04
# Epoch 90/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.0271e-04
# Epoch 91/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.0338e-04
# Epoch 92/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.1442e-04
# Epoch 93/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.2779e-04
# Epoch 94/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.7756e-04
# Epoch 95/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.3266e-04
# Epoch 96/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.8084e-04
# Epoch 97/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.3124e-04
# Epoch 98/100
# 239/239 [==============================] - 5s 21ms/step - loss: 4.1123e-04
# Epoch 99/100
# 239/239 [==============================] - 5s 20ms/step - loss: 4.3380e-04
# Epoch 100/100
# 239/239 [==============================] - 5s 20ms/step - loss: 3.9771e-04

# %%
plt.plot(history_3.history['loss'])
#plt.plot(history_3.history['val_loss'])
plt.title('model 3 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# prep inputs to get predictions

dataset_train = df.iloc[:train_size, 1:]
dataset_test = df.iloc[train_size:, 1:]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)

dataset_total.iloc[:, 0:5] = x_sc.fit_transform(dataset_total.iloc[:, 0:5])
dataset_total['Price Ratio'] = y_sc.fit_transform(dataset_total['Price Ratio'].values.reshape(-1,1))

inputs = dataset_total[len(dataset_total) - len(dataset_test) - window:].values
inputs = inputs.reshape(-1,6)

X_test = []
for i in range(window, test_size+window):
    X_test.append(inputs[i-window:i, 0:5])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 5))

# get predictions

predicted_values = model_3.predict(X_test)
predicted_values = y_sc.inverse_transform(predicted_values)

# %%
# visualising the results

plt.figure(figsize=(10, 5))
plt.plot(df.iloc[train_size:, 0], dataset_test['Price Ratio'].values, color = 'red', label = 'Real Price Ratio')
plt.plot(df.iloc[train_size:, 0], predicted_values, color = 'blue', label = 'Predicted Price Ratio')
plt.xticks(np.arange(0,test_size,50))
plt.title('Model 3 Price Ratio Prediction')
plt.xlabel('Time')
plt.ylabel('Price Ratio')
plt.legend()

plt.show()

# %%
# rmse

rmse = mean_squared_error(dataset_test['Price Ratio'].values, predicted_values, squared=False)
print(rmse)
# Out:
# 0.0005799542154963106
